# %% [markdown]
# # 강남구 (1080)
# - 작성자 : 황다은
# - 작성일자 : 2020년 9월 6일
# - 편집자 : 이준석
# - 편집일자 : 2020년 9월 6일

# %%
from bs4 import BeautifulSoup
import datetime as dt
import pandas as pd
import numpy as np
import re
from tqdm import tqdm

dat = dt.datetime.today().date() # 오늘 날짜

# %% [markdown]
# ### 1. Raw File 불러오기

# %%
df = pd.read_csv("200906one_shot.csv")
soup = BeautifulSoup(df['html'][0], 'html.parser')

# %% [markdown]
# ### 2. Regex Parsing 하기

# %%
# 너무 길어서 두 개로 나누었다. (가시적으로 표현하자.)
regex = 'tle\"\>\#(?P<num>.+?)\s확진자\\t\((?P<rsd>.+?)\).+?\/\s?(?P<dat>.+?)\<\/div.+?<li>감염경로\s\:\s?'
regex += '(?P<pth>.+?)\<\/li\>\s\<li\>(증상발현일\s\:\s)?(?P<sym>.+?)\<\/li>(.+?조치\s\:\s(?P<atn>.+?)\<\/li\>)?'

rows = soup.select('#tab-1 .acodList')
infos = [re.search(regex, str(r)) for r in rows]

# %% [markdown]
# ### 3. 저장할 DataFrame 미리 만들기

# %%
pat_col = ['num', 'dat', 'pth', 'syy', 'syd', 'cnd', 'rsd', 'atn', 'dch', 'adt']
rou_col = ['num', 'ord', 'dat', 'rgl', 'rgt', 'frm', 'exd', 'msk', 'ste', 'mob']
patient = pd.DataFrame(columns = pat_col)
route = pd.DataFrame(columns = rou_col)

# %%
new_route = pd.read_html(str(rows[4].select('table')[0]))[0]

# %% [markdown]
# ### 4. 귀찮은 전처리해주기

# %%
for i in tqdm(infos):
    
    # regex 처리가 안 되는 애들은 어차피 정보가 없으므로 None 값임.
    if i is not None:
        
        num = '1080' + '0' * (5-len(i.group('num'))) + i.group('num')
        syy = i.group('sym') != '증상 없음'
        syd = i.group('sym') * syy
        dch = ''; adt = '' # 정보가 없으면 이렇게 처리하자
        rsd, cnd, pth, sym, atn = i.group('rsd'), i.group('dat'), i.group('pth'), i.group('sym'), i.group('atn')
        new_pat = pd.DataFrame([(num, dat, pth, syy, syd, cnd, rsd, atn, dch, adt)], columns = pat_col)
        
        patient = pd.concat([patient, new_pat])
        
        new_route = pd.read_html(str(rows[4].select('table')[0]))[0]
        new_route['rgl'] = new_route.지역 + new_route.위치
        new_route['frm'] = ''; new_route['msk'] = ''
        new_route['num'] = num
        new_route['ord'] = range(1, len(new_route)+1)
        new_route['dat'] = dat
        new_route = new_route.drop(['지역', '위치'], axis = 1)
        new_route.columns = ['rgt', 'exd', 'mob', 'ste', 'rgl', 'frm', 'msk', 'num', 'ord', 'dat']
        new_route = new_route.loc[:,rou_col]
        
        route = pd.concat([route, new_route])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 143/143 [00:01<00:00, 73.95it/s]

# %% [markdown]
# ### 5. 결과 잘 나왔나 확인하기

# %%
patient
# Out:
#          num         dat     pth    syy   syd         cnd   rsd  \
# 0  108000213  2020-09-06  확진자 접촉   True   9.4  2020-09-06   세곡동
# 0  108000212  2020-09-06  확진자 접촉  False        2020-09-05   개포동
# 0  108000211  2020-09-06  확진자 접촉   True  8.29  2020-09-05   역삼동
# 0  108000210  2020-09-06  확진자 접촉   True  8.31  2020-09-05   개포동
# 0  108000209  2020-09-06      미상   True   9.3  2020-09-04   개포동
# 0  108000208  2020-09-06      미상  False        2020-09-04   개포동
# 0  108000207  2020-09-06  확진자 접촉  False        2020-09-04  압구정동
# 0  108000206  2020-09-06  확진자 접촉  False        2020-09-04  압구정동
# 0  108000205  2020-09-06  확진자 접촉  False        2020-09-04  압구정동
# 0  108000204  2020-09-06      미상   True  8.30  2020-09-04   개포동
# 0  108000203  2020-09-06  확진자 접촉   True  8.24  2020-09-03   일원동
# 0  108000202  2020-09-06  확진자 접촉   True   9.2  2020-09-03   논현동
# 0  108000201  2020-09-06  확진자 접촉   True   9.2  2020-09-03   수서동
# 0  108000200  2020-09-06  확진자 접촉   True   9.1  2020-09-03   개포동
# 0  108000199  2020-09-06  확진자 접촉   True  8.20  2020-09-02   세곡동
# 0  108000198  2020-09-06      미상   True  8.31  2020-09-02  압구정동
# 0  108000197  2020-09-06      미상   True  8.24  2020-09-02   개포동
# 0  108000196  2020-09-06  확진자 접촉   True  8.31  2020-09-02   개포동
# 0  108000195  2020-09-06  확진자 접촉  False        2020-09-01   개포동
# 0  108000194  2020-09-06  확진자 접촉  False        2020-09-01   수서동
# 0  108000193  2020-09-06      미상   True  8.30  2020-09-01   역삼동
# 0  108000192  2020-09-06   해외입국자  False        2020-09-01   역삼동
# 0  108000191  2020-09-06   해외입국자  False        2020-09-01   역삼동
# 0  108000190  2020-09-06  확진자 접촉  False        2020-09-01   세곡동
# 0  108000189  2020-09-06  확진자 접촉  False        2020-09-01   일원동
# 0  108000188  2020-09-06      미상  False        2020-09-01   대치동
# 0  108000187  2020-09-06   해외입국자  False        2020-09-01   삼성동
# 0  108000186  2020-09-06      미상  False        2020-09-01   개포동
# 0  108000185  2020-09-06  확진자 접촉   True  8.23  2020-09-01   신사동
# 0  108000184  2020-09-06      미상   True  8.27  2020-09-01   역삼동
# 0  108000183  2020-09-06  확진자 접촉   True  8.23  2020-09-01   일원동
# 0  108000182  2020-09-06  확진자 접촉   True  8.27  2020-09-01   일원동
# 0  108000181  2020-09-06      미상   True  8.24  2020-08-31   일원동
# 0  108000180  2020-09-06   해외입국자   True  8.30  2020-08-31   청담동
# 0  108000179  2020-09-06  확진자 접촉   True  8.29  2020-08-31   대치동
# 0  108000178  2020-09-06  확진자 접촉   True  8.30  2020-08-31   대치동
# 0  108000177  2020-09-06  확진자 접촉  False        2020-08-31   도곡동
# 0  108000176  2020-09-06  확진자 접촉   True  8.30  2020-08-31   도곡동
# 0  108000175  2020-09-06  확진자 접촉   True  8.24  2020-08-30   논현동
# 0  108000174  2020-09-06  확진자 접촉   True  8.28  2020-08-29   개포동
#
#                 atn dch adt
# 0              None
# 0              None
# 0              None
# 0              None
# 0              None
# 0              None
# 0              None
# 0              None
# 0              None
# 0              None
# 0      코이카생활치료센터 이송
# 0      코이카생활치료센터 이송
# 0       남산생활치료센터 이송
# 0      코이카생활치료센터 이송
# 0  9.3 코이카생활치료센터 이송
# 0          서울의료원 이송
# 0          서울의료원 이송
# 0       태릉생활치료센터 이송
# 0   9.2 태릉생활치료센터 이송
# 0              None
# 0         강북삼성병원 이송
# 0  9.2 코이카생활치료센터 이송
# 0  9.2 코이카생활치료센터 이송
# 0      코이카생활치료센터 이송
# 0          서울의료원 이송
# 0  9.2 코이카생활치료센터 이송
# 0  9.2 코이카생활치료센터 이송
# 0           서북병원 이송
# 0           서남병원 이송
# 0       태릉생활치료센터 이송
# 0       남산생활치료센터 이송
# 0          적십자병원 이송
# 0         삼성서울병원 이송
# 0       은평생활치료센터 이송
# 0          보라매병원 이송
# 0       은평생활치료센터 이송
# 0   9.1 남산생활치료센터 이송
# 0   9.1 남산생활치료센터 이송
# 0          보라매병원 이송
# 0     8.31 원자력병원 이송

# %%
route.head(3)
# Out:
#          num ord         dat           rgl  rgt frm                   exd msk  \
# 0  108000213   1  2020-09-06  개포동대청역 1번 출구   카페            - 9.1(화) 16:15
# 1  108000213   2  2020-09-06  개포동대청역 1번 출구  편의점      - 9.2(화) 12:00~12:20
# 2  108000213   3  2020-09-06  개포동대청역 1번 출구  편의점            - 9.2(화) 18:43
#
#   ste  mob
# 0  완료   도보
# 1  완료  NaN
# 2  완료  NaN
